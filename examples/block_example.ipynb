# %%
# !pip3 install -e .. --config-settings editable_mode=strict
# Out:
# Obtaining file:///Users/guycohen/Desktop/research/code-theory
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for block (pyproject.toml) ... done
#   Created wheel for block: filename=block-0.1.0-0.editable-py3-none-any.whl size=4232 sha256=a325161704c490ffa172852507c4bb42126f5a16f6604248fd6cecc09fffdcc3
#   Stored in directory: /private/var/folders/nn/xzzlts8n4cz51ztmk6jjhzr80000gn/T/pip-ephem-wheel-cache-2axfd_7z/wheels/15/7d/32/372f037f504e8f71df6dc0f58feded2c9afd2fee41f669835c
# Successfully built block
# ...
#   Attempting uninstall: block
#     Found existing installation: block 0.1.0
#     Uninstalling block-0.1.0:
#       Successfully uninstalled block-0.1.0
# ...

# %%
# !pip3 list
# Out:
# Package             Version     Editable project location
# ------------------- ----------- --------------------------------------------
# appnope             0.1.4
# asttokens           3.0.0
# black               24.3.0
# block               0.1.0       /Users/guycohen/Desktop/research/code-theory
# Brotli              1.1.0
# certifi             2025.1.31
# cffi                1.16.0
# charset-normalizer  3.3.2
# click               8.1.7
# colorama            0.4.6
# comm                0.2.2
# contourpy           1.2.0
# cse446utils         0.0.1
# cycler              0.12.1
# debugpy             1.8.5
# decorator           5.2.1
# exceptiongroup      1.2.2
# executing           2.1.0
# flake8              7.0.0
# fonttools           4.50.0
# future              1.0.0
# gradescope-utils    0.4.0
# idna                3.6
# importlib_metadata  8.6.1
# importlib_resources 6.4.0
# invoke              2.2.0
# ipykernel           6.29.5
# ipython             8.18.1
# ...
